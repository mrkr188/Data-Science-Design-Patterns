# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Countplots

# %%
plt.figure(figsize=(8,8))
sns.countplot(x="sex", hue="class", data=titanic)
plt.xlabel("Sex")
plt.ylabel("Counts")
plt.show()

# %%
sns.catplot(x="sex", hue="class", row="pclass", col="alive", data=titanic, kind="count")
plt.show()

# %% [markdown]
# # Distribution plots

# %%
plt.figure(figsize=(8,8))
sns.distplot(a=titanic.age.dropna(), rug=False, hist=True, kde=True)
plt.axvline(titanic.age.mean(), color='b', linestyle='dashed', linewidth=1)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.distplot(a=titanic.age.dropna(), rug=False, hist=False, kde=True)
plt.axvline(titanic.age.mean(), color='b', linestyle='dashed', linewidth=1)
plt.show()

# %% [markdown]
# # Box plots

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="sex", y="age", hue='class', data=titanic)
plt.show()

# %% [markdown]
# # Violin Plot

# %%
plt.figure(figsize=(12,8))
sns.violinplot(x="sex", y="age", hue='class', data=titanic)
plt.show()

# %% [markdown]
# # Bar Plot

# %%
plt.figure(figsize=(12,8))
sns.barplot(x="class", y="fare", hue="sex", data=titanic)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="age", y="fare", hue='sex', data=titanic)
plt.show()

# %% [markdown]
# # Subplots

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 8))
sns.barplot(x="class", y="fare", data=titanic, ax=ax1)
sns.barplot(x="sex", y="fare", data=titanic, ax=ax2)
plt.show()

# %% [markdown]
# # Pair plot

# %%
plt.figure(figsize=(12,12))
sns.pairplot(titanic, vars=['pclass', 'alone', 'survived', 'age', 'fare'], hue = 'sex', palette='husl')
plt.show()

# %% [markdown]
# # Normal Matplotlib

# %%
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)
data = np.column_stack((x, y))

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

ax1.scatter(x=x, y=y, marker='o', c='r', edgecolor='b')
ax1.set_title('Scatter: $x$ versus $y$')
ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')

ax2.hist(data, bins=np.arange(data.min(), data.max()), label=('x', 'y'))
ax2.legend(loc=(0.65, 0.8))
ax2.set_title('Frequencies of $x$ and $y$')
ax2.yaxis.tick_right()

plt.show()
